# %%
#Import dependencies
import pandas as pd
import numpy as np
import os

# %%
# Import CSV and convert to dataframes
Poverty_df = pd.read_csv(os.path.join("Resources", "Poverty_rates__by_county.csv"))

# %%
Poverty_df
# Out:
#     Number   FIPS       State       County  Poverty Rate 1960  \
# 0      NaN     34  New Jersey  State Total               11.3
# 1   1775.0  34001  New Jersey    Atlantic                22.8
# 2   1776.0  34003  New Jersey      Bergen                 5.4
# 3   1777.0  34005  New Jersey  Burlington                12.3
# 4   1778.0  34007  New Jersey      Camden                12.1
# 5   1779.0  34009  New Jersey    Cape May                22.0
# 6   1780.0  34011  New Jersey  Cumberland                20.9
# 7   1781.0  34013  New Jersey       Essex                13.8
# 8   1782.0  34015  New Jersey  Gloucester                13.6
# 9   1783.0  34017  New Jersey      Hudson                12.9
# 10  1784.0  34019  New Jersey   Hunterdon                13.7
# 11  1785.0  34021  New Jersey      Mercer                12.0
# 12  1786.0  34023  New Jersey   Middlesex                 7.7
# 13  1787.0  34025  New Jersey    Monmouth                13.8
# ...

# %%
Poverty_df.drop(['Number', 'FIPS'],axis=1)
# Out:
#          State       County  Poverty Rate 1960  Poverty Rate 1970  \
# 0   New Jersey  State Total               11.3                8.1
# 1   New Jersey    Atlantic                22.8               13.0
# 2   New Jersey      Bergen                 5.4                4.1
# 3   New Jersey  Burlington                12.3                6.3
# 4   New Jersey      Camden                12.1                8.9
# 5   New Jersey    Cape May                22.0               12.4
# 6   New Jersey  Cumberland                20.9               11.8
# 7   New Jersey       Essex                13.8               13.1
# 8   New Jersey  Gloucester                13.6                7.8
# 9   New Jersey      Hudson                12.9               11.9
# 10  New Jersey   Hunterdon                13.7                6.3
# 11  New Jersey      Mercer                12.0                9.3
# 12  New Jersey   Middlesex                 7.7                5.3
# ...

# %%
Poverty_df = Poverty_df.drop('Number',axis=1)

# %%
Poverty_df =  Poverty_df.drop(Poverty_df.index[0])

# %%
Poverty_df.dtypes
# Out:
# FIPS                         int64
# State                       object
# County                      object
# Poverty Rate 1960          float64
# Poverty Rate 1970          float64
# Poverty Rate 1980          float64
# Poverty Rate 1990          float64
# Poverty Rate 2000          float64
# Poverty Rate 2010          float64
# Population 1960             object
# Population 1970             object
# Population 1980             object
# Population 1990             object
# Population 2000             object
# Population 2010             object
# Persons in Poverty 1960     object
# Persons in Poverty 1970     object
# Persons in Poverty 1980     object
# Persons in Poverty 1990     object
# Persons in Poverty 2000     object
# Persons in Poverty 2010     object
# dtype: object

# %%
# Change Income column to integer value
#Poverty_df["Population 1960"] = Poverty_df["Population 1960"].astype('float64')
Poverty_df["Population 1960"] = Poverty_df["Population 1960"].str.replace(",","").astype(int)
Poverty_df["Population 1970"] = Poverty_df["Population 1970"].str.replace(",","").astype(int)
Poverty_df["Population 1980"] = Poverty_df["Population 1980"].str.replace(",","").astype(int)
Poverty_df["Population 1990"] = Poverty_df["Population 1990"].str.replace(",","").astype(int)
Poverty_df["Population 2000"] = Poverty_df["Population 2000"].str.replace(",","").astype(int)
Poverty_df["Population 2010"] = Poverty_df["Population 2010"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 1960"] = Poverty_df["Persons in Poverty 1960"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 1970"] = Poverty_df["Persons in Poverty 1970"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 1980"] = Poverty_df["Persons in Poverty 1980"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 1990"] = Poverty_df["Persons in Poverty 1990"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 2000"] = Poverty_df["Persons in Poverty 2000"].str.replace(",","").astype(int)
Poverty_df["Persons in Poverty 2010"] = Poverty_df["Persons in Poverty 2010"].str.replace(",","").astype(int)

# %%
Poverty_df
# Out:
#      FIPS       State       County  Poverty Rate 1960  Poverty Rate 1970  \
# 1   34001  New Jersey    Atlantic                22.8               13.0
# 2   34003  New Jersey      Bergen                 5.4                4.1
# 3   34005  New Jersey  Burlington                12.3                6.3
# 4   34007  New Jersey      Camden                12.1                8.9
# 5   34009  New Jersey    Cape May                22.0               12.4
# 6   34011  New Jersey  Cumberland                20.9               11.8
# 7   34013  New Jersey       Essex                13.8               13.1
# 8   34015  New Jersey  Gloucester                13.6                7.8
# 9   34017  New Jersey      Hudson                12.9               11.9
# 10  34019  New Jersey   Hunterdon                13.7                6.3
# 11  34021  New Jersey      Mercer                12.0                9.3
# 12  34023  New Jersey   Middlesex                 7.7                5.3
# ...

# %%
# replace unique values
Poverty_df = Poverty_df.replace(",","" )

# %%
# Change Income column to interger value
#Poverty_df["Population 1960"] = pd.to_numeric(Poverty_df["Population 1960"])

# %%
Poverty_df
# Out:
#      FIPS       State       County  Poverty Rate 1960  Poverty Rate 1970  \
# 1   34001  New Jersey    Atlantic                22.8               13.0
# 2   34003  New Jersey      Bergen                 5.4                4.1
# 3   34005  New Jersey  Burlington                12.3                6.3
# 4   34007  New Jersey      Camden                12.1                8.9
# 5   34009  New Jersey    Cape May                22.0               12.4
# 6   34011  New Jersey  Cumberland                20.9               11.8
# 7   34013  New Jersey       Essex                13.8               13.1
# 8   34015  New Jersey  Gloucester                13.6                7.8
# 9   34017  New Jersey      Hudson                12.9               11.9
# 10  34019  New Jersey   Hunterdon                13.7                6.3
# 11  34021  New Jersey      Mercer                12.0                9.3
# 12  34023  New Jersey   Middlesex                 7.7                5.3
# ...

# %%
Poverty_df.dtypes
# Out:
# FIPS                         int64
# State                       object
# County                      object
# Poverty Rate 1960          float64
# Poverty Rate 1970          float64
# Poverty Rate 1980          float64
# Poverty Rate 1990          float64
# Poverty Rate 2000          float64
# Poverty Rate 2010          float64
# Population 1960              int64
# Population 1970              int64
# Population 1980              int64
# Population 1990              int64
# Population 2000              int64
# Population 2010              int64
# Persons in Poverty 1960      int64
# Persons in Poverty 1970      int64
# Persons in Poverty 1980      int64
# Persons in Poverty 1990      int64
# Persons in Poverty 2000      int64
# Persons in Poverty 2010      int64
# dtype: object

# %%
Poverty_df = Poverty_df.drop('FIPS',axis=1)

# %%
Poverty_df = Poverty_df.drop('State',axis=1)

# %%
Poverty_df
# Out:
#          County  Poverty Rate 1960  Poverty Rate 1970  Poverty Rate 1980  \
# 1     Atlantic                22.8               13.0               12.6
# 2       Bergen                 5.4                4.1                4.1
# 3   Burlington                12.3                6.3                6.3
# 4       Camden                12.1                8.9               11.8
# 5     Cape May                22.0               12.4                9.1
# 6   Cumberland                20.9               11.8               14.5
# 7        Essex                13.8               13.1               17.9
# 8   Gloucester                13.6                7.8                8.6
# 9       Hudson                12.9               11.9               16.9
# 10   Hunterdon                13.7                6.3                4.4
# 11      Mercer                12.0                9.3                9.4
# 12   Middlesex                 7.7                5.3                6.3
# ...

# %%
#Import dependencies
import pandas as pd
import numpy as np
import os

# %%
# Import CSV and convert to dataframes
IncomeSDs_df = pd.read_csv(os.path.join("Resources", "ACS_17_5YR_S1901_with_ann.csv"))

# %%
IncomeSDs_df
# Out:
#                GEO.id  GEO.id2  \
# 0    9700000US3400004  3400004
# 1    9700000US3400008  3400008
# 2    9700000US3400009  3400009
# 3    9700000US3400660  3400660
# 4    9700000US3400720  3400720
# 5    9700000US3400769  3400769
# 6    9700000US3400780  3400780
# 7    9700000US3400810  3400810
# 8    9700000US3400840  3400840
# 9    9700000US3400870  3400870
# 10   9700000US3400900  3400900
# 11   9700000US3400930  3400930
# 12   9700000US3400960  3400960
# 13   9700000US3401050  3401050
# 14   9700000US3401110  3401110
# 15   9700000US3401140  3401140
# 16   9700000US3401170  3401170
# 17   9700000US3401230  3401230
# 18   9700000US3401260  3401260
# 19   9700000US3401320  3401320
# 20   9700000US3401350  3401350
# 21   9700000US3401410  3401410
# 22   9700000US3401440  3401440
# 23   9700000US3401500  3401500
# 24   9700000US3401530  3401530
# 25   9700000US3401620  3401620
# 26   9700000US3401650  3401650
# 27   9700000US3401740  3401740
# 28   9700000US3401830  3401830
# ...

# %%
IncomeSDs_df = IncomeSDs_df[['GEO.id','GEO.id2','GEO.display-label', 'HC01_EST_VC13']]

# %%
IncomeSDs_df
# Out:
#                GEO.id  GEO.id2  \
# 0    9700000US3400004  3400004
# 1    9700000US3400008  3400008
# 2    9700000US3400009  3400009
# 3    9700000US3400660  3400660
# 4    9700000US3400720  3400720
# 5    9700000US3400769  3400769
# 6    9700000US3400780  3400780
# 7    9700000US3400810  3400810
# 8    9700000US3400840  3400840
# 9    9700000US3400870  3400870
# 10   9700000US3400900  3400900
# 11   9700000US3400930  3400930
# 12   9700000US3400960  3400960
# 13   9700000US3401050  3401050
# 14   9700000US3401110  3401110
# 15   9700000US3401140  3401140
# 16   9700000US3401170  3401170
# 17   9700000US3401230  3401230
# 18   9700000US3401260  3401260
# 19   9700000US3401320  3401320
# 20   9700000US3401350  3401350
# 21   9700000US3401410  3401410
# 22   9700000US3401440  3401440
# 23   9700000US3401500  3401500
# 24   9700000US3401530  3401530
# 25   9700000US3401620  3401620
# 26   9700000US3401650  3401650
# 27   9700000US3401740  3401740
# 28   9700000US3401830  3401830
# ...

# %%
IncomeSDs_df.rename( index=str, columns = {"GEO.display-label": "School District","HC01_EST_VC13": "Median Household Income"})
# Out:
#                GEO.id  GEO.id2  \
# 0    9700000US3400004  3400004
# 1    9700000US3400008  3400008
# 2    9700000US3400009  3400009
# 3    9700000US3400660  3400660
# 4    9700000US3400720  3400720
# 5    9700000US3400769  3400769
# 6    9700000US3400780  3400780
# 7    9700000US3400810  3400810
# 8    9700000US3400840  3400840
# 9    9700000US3400870  3400870
# 10   9700000US3400900  3400900
# 11   9700000US3400930  3400930
# 12   9700000US3400960  3400960
# 13   9700000US3401050  3401050
# 14   9700000US3401110  3401110
# 15   9700000US3401140  3401140
# 16   9700000US3401170  3401170
# 17   9700000US3401230  3401230
# 18   9700000US3401260  3401260
# 19   9700000US3401320  3401320
# 20   9700000US3401350  3401350
# 21   9700000US3401410  3401410
# 22   9700000US3401440  3401440
# 23   9700000US3401500  3401500
# 24   9700000US3401530  3401530
# 25   9700000US3401620  3401620
# 26   9700000US3401650  3401650
# 27   9700000US3401740  3401740
# 28   9700000US3401830  3401830
# ...

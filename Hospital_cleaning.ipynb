# %%
#Import dependencies
import pandas as pd
import numpy as np
import os

# %%
# Import CSV and convert to dataframes
Hospitals_df = pd.read_csv(os.path.join("Resources", "Hospital_General_Info_NJ.csv"))

# %% [markdown]
# ### Clean Hospitals dataframe

# %%
Hospitals_df.head()
# Out:
#    Provider ID                            Hospital Name  \
# 0     310009.0               CLARA MAASS MEDICAL CENTER
# 1     310010.0   PENN MEDICINE PRINCETON MEDICAL CENTER
# 2     310011.0         CAPE REGIONAL MEDICAL CENTER INC
# 3     310034.0                 RIVERVIEW MEDICAL CENTER
# 4     310038.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
#
#                          Address                  City State  ZIP Code  \
# 0          ONE CLARA MAASS DRIVE            BELLEVILLE    NJ    7109.0
# 1            ONE PLAINSBORO ROAD            PLAINSBORO    NJ    8536.0
# 2          TWO STONE HARBOR BLVD  CAPE MAY COURT HOUSE    NJ    8210.0
# 3            ONE RIVERVIEW PLAZA              RED BANK    NJ    7701.0
# 4  ONE ROBERT WOOD JOHNSON PLACE         NEW BRUNSWICK    NJ    8901.0
#
#   County Name  Phone Number         Hospital Type  \
# 0       ESSEX  9.734502e+09  Acute Care Hospitals
# 1   MIDDLESEX  8.664605e+09  Acute Care Hospitals
# ...

# %%
NJHospitals_df = Hospitals_df[['Provider ID', 'Hospital Name', 'Address', 'City', 'State','ZIP Code', 'County Name', 'Hospital Type','Location']]

# %%
NJHospitals_df
# Out:
#       Provider ID                                     Hospital Name  \
# 0        310009.0                        CLARA MAASS MEDICAL CENTER
# 1        310010.0            PENN MEDICINE PRINCETON MEDICAL CENTER
# 2        310011.0                  CAPE REGIONAL MEDICAL CENTER INC
# 3        310034.0                          RIVERVIEW MEDICAL CENTER
# 4        310038.0           ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL
# 5        310044.0          CAPITAL HEALTH MEDICAL CENTER - HOPEWELL
# 6        310054.0                       HACKENSACK-UMC MOUNTAINSIDE
# 7        310073.0            JERSEY SHORE UNIVERSITY MEDICAL CENTER
# 8        310110.0  ROBERT WOOD JOHNSON UNIVERSITY HOSPITAL HAMILTON
# 9         50101.0                      SUTTER SOLANO MEDICAL CENTER
# 10       110105.0                  COLQUITT REGIONAL MEDICAL CENTER
# 11       100088.0               BAPTIST MEDICAL CENTER JACKSONVILLE
# 12        41310.0                       STONE COUNTY MEDICAL CENTER
# ...

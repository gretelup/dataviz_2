# %%
#Import Dependencies
import pandas as pd
import numpy as np
import os

# %%
# Import CSV and convert to dataframes
NJHousehold_df = pd.read_csv(os.path.join("Resources", "NJ_Household_Income.csv"))

# %%
### Display DataFrame of NJ_Household_Incomes
NJHousehold_df
# Out:
#          State      County  Household Income  95% CI - Low  95% CI - High  \
# 0   New Jersey         NaN             80106         79326          80886
# 1   New Jersey    Atlantic             59309         55159          63459
# 2   New Jersey      Bergen             93805         90273          97337
# 3   New Jersey  Burlington             86777         83107          90447
# 4   New Jersey      Camden             65817         62849          68785
# 5   New Jersey    Cape May             64450         60890          68010
# 6   New Jersey  Cumberland             51786         48058          55514
# 7   New Jersey       Essex             60284         57891          62677
# 8   New Jersey  Gloucester             84639         79660          89618
# 9   New Jersey      Hudson             65673         61919          69427
# 10  New Jersey   Hunterdon            113083        104707         121459
# 11  New Jersey      Mercer             78161         73123          83199
# ...

# %%
NJcleanhouse_df = NJHousehold_df.drop(NJHousehold_df.index[0])

# %%
NJcleanhouse_df
# Out:
#          State      County  Household Income  95% CI - Low  95% CI - High  \
# 1   New Jersey    Atlantic             59309         55159          63459
# 2   New Jersey      Bergen             93805         90273          97337
# 3   New Jersey  Burlington             86777         83107          90447
# 4   New Jersey      Camden             65817         62849          68785
# 5   New Jersey    Cape May             64450         60890          68010
# 6   New Jersey  Cumberland             51786         48058          55514
# 7   New Jersey       Essex             60284         57891          62677
# 8   New Jersey  Gloucester             84639         79660          89618
# 9   New Jersey      Hudson             65673         61919          69427
# 10  New Jersey   Hunterdon            113083        104707         121459
# 11  New Jersey      Mercer             78161         73123          83199
# 12  New Jersey   Middlesex             85187         82993          87381
# ...
